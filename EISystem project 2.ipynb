# %%
import pandas as pd

# %%
df=pd.read_csv("C://Users//Sunny//Desktop//multiple dependent project 2.csv")

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600         3   20  550000
# 1  3000         4   15  565000
# 2  3200         3   18  610000
# 3  3600         3   30  595000
# 4  4000         5    8  760000

# %%
x=df[["area","bedrooms","age"]]

# %%
x
# Out:
#    area  bedrooms  age
# 0  2600         3   20
# 1  3000         4   15
# 2  3200         3   18
# 3  3600         3   30
# 4  4000         5    8

# %%
y=df.price

# %%
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    595000
# 4    760000
# Name: price, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x["bedrooms"],y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([   137.25, -26025.  ,  -6825.  ])

# %%
model.intercept_
# Out:
# 383724.99999999977

# %%
model.predict(x)
# Out:
# array([526000., 589000., 622000., 595000., 748000.])

# %%
model.predict([[5000,3,5]])
# Out:
# C:\Users\Sunny\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([957775.])
